# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
sns.regplot(x='total_bill',y='tip', data=tips)

# %%
sns.regplot(x='total_bill',y='tip', data=tips, scatter_kws={'marker':'D','color':'blue'}, line_kws={'color':'red',"linewidth":3})
# chaning marker and line color

# %%
sns.regplot(x='total_bill',y='tip', data=tips, ci=100) # showing confidence intercal in form of shade

# %%
sns.regplot(x='size',y='tip', data=tips, x_estimator=np.mean) #  dot showing mean and line showing CI
