# %%
import pandas as pd

# %%
df=pd.read_csv("appledata.csv", parse_dates=["Date"])

# %%
type(df['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# df.set_index("Date", inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
df['2017-07'] #Of 7th month only
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848

# %%
# %matplotlib inline
df.Close.mean() # mean of all column
df['2017-07']["Close"].mean()# mean of specific month in column
df['2017-07-6':'2017-07-1']
df.Close.resample('Q').mean().plot(kind="bar", color='g')  #Resample the data into month and mean it

# %%
df=pd.read_csv("data_range.csv")
drange=pd.date_range(start='1/1/2016',end='18/12/2016', freq='B')
drange
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-04', '2016-01-05', '2016-01-06',
#                '2016-01-07', '2016-01-08', '2016-01-11', '2016-01-12',
#                '2016-01-13', '2016-01-14',
#                ...
#                '2016-12-05', '2016-12-06', '2016-12-07', '2016-12-08',
#                '2016-12-09', '2016-12-12', '2016-12-13', '2016-12-14',
#                '2016-12-15', '2016-12-16'],
#               dtype='datetime64[ns]', length=251, freq='B')

# %%
df.set_index(drange, inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2016-01-01  142.90  144.75  142.90  144.18  19201712
# 2016-01-04  143.02  143.50  142.41  142.73  24128782
# 2016-01-05  143.69  144.79  142.72  144.09  21569557
# 2016-01-06  144.88  145.30  143.10  143.50  14277848
# 2016-01-07  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-12-12   98.92   99.30   98.50   98.78  30136990
# 2016-12-13   97.39   98.99   97.32   98.79  38918997
# 2016-12-14   97.41   97.67   96.84   96.87  25892171
# 2016-12-15   97.17   97.70   97.12   97.42  24167463
# 2016-12-16   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
# %matplotlib inline
df.Close.plot()

# %%
#to inlcude holidays and assuming previous day closing on weekends use
df.asfreq("D", method="pad") #H,D,W hour,day , week
# Out:
#               Open    High     Low   Close    Volume
# 2016-01-01  142.90  144.75  142.90  144.18  19201712
# 2016-01-02  142.90  144.75  142.90  144.18  19201712
# 2016-01-03  142.90  144.75  142.90  144.18  19201712
# 2016-01-04  143.02  143.50  142.41  142.73  24128782
# 2016-01-05  143.69  144.79  142.72  144.09  21569557
# ...            ...     ...     ...     ...       ...
# 2016-12-12   98.92   99.30   98.50   98.78  30136990
# 2016-12-13   97.39   98.99   97.32   98.79  38918997
# 2016-12-14   97.41   97.67   96.84   96.87  25892171
# 2016-12-15   97.17   97.70   97.12   97.42  24167463
# 2016-12-16   96.75   97.65   96.73   96.98  23794945
#
# [351 rows x 5 columns]

# %%
df=pd.read_csv("data_range.csv")
drange=pd.date_range(start='1/1/2016',periods=251, freq='H')  #if you do not know end date ,but know value
drange
# Out:
# DatetimeIndex(['2016-01-01 00:00:00', '2016-01-01 01:00:00',
#                '2016-01-01 02:00:00', '2016-01-01 03:00:00',
#                '2016-01-01 04:00:00', '2016-01-01 05:00:00',
#                '2016-01-01 06:00:00', '2016-01-01 07:00:00',
#                '2016-01-01 08:00:00', '2016-01-01 09:00:00',
#                ...
#                '2016-01-11 01:00:00', '2016-01-11 02:00:00',
#                '2016-01-11 03:00:00', '2016-01-11 04:00:00',
#                '2016-01-11 05:00:00', '2016-01-11 06:00:00',
#                '2016-01-11 07:00:00', '2016-01-11 08:00:00',
#                '2016-01-11 09:00:00', '2016-01-11 10:00:00'],
#               dtype='datetime64[ns]', length=251, freq='H')

# %%
df.set_index(drange)
# Out:
#                        Open    High     Low   Close    Volume
# 2016-01-01 00:00:00  142.90  144.75  142.90  144.18  19201712
# 2016-01-01 01:00:00  143.02  143.50  142.41  142.73  24128782
# 2016-01-01 02:00:00  143.69  144.79  142.72  144.09  21569557
# 2016-01-01 03:00:00  144.88  145.30  143.10  143.50  14277848
# 2016-01-01 04:00:00  144.45  144.96  143.78  144.02  23024107
# ...                     ...     ...     ...     ...       ...
# 2016-01-11 06:00:00   98.92   99.30   98.50   98.78  30136990
# 2016-01-11 07:00:00   97.39   98.99   97.32   98.79  38918997
# 2016-01-11 08:00:00   97.41   97.67   96.84   96.87  25892171
# 2016-01-11 09:00:00   97.17   97.70   97.12   97.42  24167463
# 2016-01-11 10:00:00   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
#How to handle HOLIDAYS####
df1=pd.read_csv("usa.csv")
df1
dr=pd.date_range(start="1-7-2017", periods=6, freq="B")
dr
# Out:
# DatetimeIndex(['2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-16'],
#               dtype='datetime64[ns]', freq='B')

# %%
df1.set_index(dr)
# Out:
#                  Date    Open    High     Low   Close    Volume
# 2017-01-09  01-Jul-17  142.90  144.75  142.90  144.18  19201712
# 2017-01-10  06-Jul-17  143.02  143.50  142.41  142.73  24128782
# 2017-01-11  05-Jul-17  143.69  144.79  142.72  144.09  21569557
# 2017-01-12  03-Jul-17  144.88  145.30  143.10  143.50  14277848
# 2017-01-13  30-Jun-17  144.45  144.96  143.78  144.02  23024107
# 2017-01-16  29-Jun-17  144.71  145.13  142.28  143.68  31499368
