# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("tmdb_5000_movies.csv") 
df.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %% [markdown]
# ### Raw Selection. (always provide range)
# ### Columns Selection ( write column name)

# %%
df[start point:end point] #it will show end-1 row.
df[0:10]    # 0 to 10 rows
df[0:10:2]  # 0 to 10 rows with step size 2
df[10:0:-2] #10 to zero rows with step size 2  
#One thing to note that it will always start from start and go to end point irrespective of direction.
# Out:
#   File "<ipython-input-90-38ff18374959>", line 1
#     df[start point:end point] #it will show end-1 row.
#                  ^
# SyntaxError: invalid syntax

# %%
df['original_title']
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4798                                 El Mariachi
# 4799                                   Newlyweds
# 4800                   Signed, Sealed, Delivered
# 4801                            Shanghai Calling
# 4802                           My Date with Drew
# Name: original_title, Length: 4803, dtype: object

# %% [markdown]
# ## row and column selection

# %%
df[1:9]['homepage']
# Out:
# 1         http://disney.go.com/disneypictures/pirates/
# 2          http://www.sonypictures.com/movies/spectre/
# 3                   http://www.thedarkknightrises.com/
# 4                 http://movies.disney.com/john-carter
# 5      http://www.sonypictures.com/movies/spider-man3/
# 6         http://disney.go.com/disneypictures/tangled/
# 7    http://marvel.com/movies/movie/193/avengers_ag...
# 8    http://harrypotter.warnerbros.com/harrypottera...
# Name: homepage, dtype: object

# %%
#multiple raw and columns #Pass the list
df[1:4][['homepage','original_title']]
# Out:
#                                        homepage  \
# 1  http://disney.go.com/disneypictures/pirates/
# 2   http://www.sonypictures.com/movies/spectre/
# 3            http://www.thedarkknightrises.com/
#
#                              original_title
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises

# %% [markdown]
# # # row and column selection in  one line.(pd.loc[row range, column name])
# ## Only work for labels

# %%
df.loc[1:5,['homepage','original_title','revenue']]
# Out:
#                                           homepage  \
# 1     http://disney.go.com/disneypictures/pirates/
# 2      http://www.sonypictures.com/movies/spectre/
# 3               http://www.thedarkknightrises.com/
# 4             http://movies.disney.com/john-carter
# 5  http://www.sonypictures.com/movies/spider-man3/
#
#                              original_title     revenue
# 1  Pirates of the Caribbean: At World's End   961000000
# 2                                   Spectre   880674609
# 3                     The Dark Knight Rises  1084939099
# 4                               John Carter   284139100
# 5                              Spider-Man 3   890871626

# %% [markdown]
# # # row and column selection in  one line.(pd.iloc[row range, column name])
# ## will only work when columns and rows are have integer index.

# %%
df.iloc[34:88,7:9]
#Here you need to provide integers
# Out:
#                                              overview  popularity
# 34  A look at the relationship between Mike and Su...   89.186492
# 35  Sam Witwicky leaves the Autobots behind for a ...   21.939663
# 36  As humanity picks up the pieces, following the...  116.840296
# 37  Oscar Diggs, a small-time circus illusionist a...   46.985445
# 38  For Peter Parker, life is busy. Between taking...   89.270217
# 39  Sam Flynn, the tech-savvy and daring son of Ke...   73.795050
# 40  Star race car Lightning McQueen and his pal Ma...   49.986590
# 41  For centuries, a small but powerful force of w...   51.872839
# 42  Woody, Buzz, and the rest of Andy's toys haven...   59.995418
# 43  All grown up in post-apocalyptic 2018, John Co...   71.862892
# 44  Deckard Shaw seeks revenge against Dominic Tor...  102.322217
# 45  Life for former United Nations investigator Ge...   81.834855
# 46  The ultimate X-Men ensemble fights a war for t...  118.078691
# ...

# %% [markdown]
# #}

# %% [markdown]
# # End of Tutorial#
