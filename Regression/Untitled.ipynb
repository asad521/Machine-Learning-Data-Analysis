# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def grd(x,y):
    m_cur=0
    b_cur=0
    iteration=100
    ss=0.01 # step size, iteration step, learning rate3
    n=len(x)
    for i in range(iteration):
                
        y_predicted=x*m_cur+b_cur
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        dm= -(2/n)*sum(x*(y-y_predicted))
        db= -(2/n)*sum(y-y_predicted)
        m_cur=m_cur- ss*dm
        b_cur=b_cur-ss*db
        print(f"Value of slope  is:{m_cur}, Value of b is:{b_cur}\n Value of dm is :{dm} and value of db:{db}\n Value"
              +f"is cost is {cost}")
        plt.scatter(x,y, color='blue')  #plot previous plot
        plt.plot(x,y_predicted, color='red')
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
grd(x,y)
# Out:
# Value of slope  is:0.62, Value of b is:0.18
#  Value of dm is :-62.0 and value of db:-18.0
#  Valueis cost is 89.0
# Value of slope  is:1.0928, Value of b is:0.3192
#  Value of dm is :-47.28 and value of db:-13.92
#  Valueis cost is 52.25039999999999
# Value of slope  is:1.453232, Value of b is:0.42724799999999996
#  Value of dm is :-36.043200000000006 and value of db:-10.8048
#  Valueis cost is 30.831949440000002
# Value of slope  is:1.7278860800000002, Value of b is:0.5115091199999999
#  Value of dm is :-27.465408000000004 and value of db:-8.426112000000002
#  Valueis cost is 18.347751350784
# Value of slope  is:1.9370605952000002, Value of b is:0.5776057727999999
#  Value of dm is :-20.917451519999997 and value of db:-6.609665279999999
#  Valueis cost is 11.070010749324897
# Value of slope  is:2.096250917888, Value of b is:0.6298300216319999
#  Value of dm is :-15.919032268799995 and value of db:-5.222424883199999
#  Valueis cost is 6.826353152519786
# ...
