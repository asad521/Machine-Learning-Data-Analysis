# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

def grd(x,y):
    m_cur=0
    b_cur=0
    iteration=10000
    ss=0.001 # step size, iteration step, learning rate3
    n=len(x)
    for i in range(iteration):
                
        y_predicted=x*m_cur+b_cur
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        dm= -(2/n)*sum(x*(y-y_predicted))
        db= -(2/n)*sum(y-y_predicted)
        m_cur=m_cur- ss*dm
        b_cur=b_cur-ss*db
        print(f"Value of slope  is:{m_cur}, Value of intercept is:{b_cur}\n Value"
              +f"is cost is {cost}")
        plt.scatter(x,y, color='blue')  #plot previous plot
        plt.plot(x,y_predicted, color='red')
#         plt.ylim([0,20])
#         plt.xlim([0,50])
# x = np.array([12,23,33,44,54])
# y = np.array([5,7,9,11,13])
# x = np.array([2,3,5,13,8,16,11,1,9])
# y = np.array([15,28,42,64,50,90,58,8,54])
y=np.array([550000,565000,610000,680000,725000])
x=np.array([2600,300,3200,3400,4000])

grd(x,y)
##There is one confusion that both m and b start from 0 values  and then gradually increase with same stop size. 
#Then question arrise 1)How b values get change after 1000 iteration. Both values of m and b should be same.
# 2)B and m values should also not be same, because it does not necessary that m and y will be zero at slope
###########
# There values get change because both calculation the dereviate of line equation seprative and then change is subtracted 
# from learning rate and step size. Means new value  of slop and b is depends on previous values- stepsize and derivative
#One more thing, above algorithem will not tell which value of m and b is perfect .you will have to calculate cost function
# on each iteration(each value of m and b) to check which value of m and b give minimum cost function.
########+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++##########
# WAHT WE ARE DOING ACUTALLY.
# ACUTALY WE ARE Derrivatin the cost function with respect to m and b one by one. 
# means we are finding "change" of cost function with repsect to m and b
# then we use those changes to find value of m and b 
# then we put those value in cost function of equation to check whether cost function reduces or not
# and keep repeating these steps
# Out:
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in long_scalars
#   if sys.path[0] == '':
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: overflow encountered in long_scalars
#   del sys.path[0]
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in double_scalars
#   if sys.path[0] == '':
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in double_scalars
#   if sys.path[0] == '':
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in double_scalars
#   if sys.path[0] == '':
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in double_scalars
#   if sys.path[0] == '':
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
# Some example data to display
x = np.array([2,3,5,13,8,16,11,1,9])
y = np.array([15,28,42,64,50,90,58,8,54])
reg = linear_model.LinearRegression()
x=x.reshape(-1, 1)
y=y.reshape(-1,1)
reg.fit(x,y)
reg.coef_
# %matplotlib inline
plt.scatter(x,y, color='black')  #plot previous plot
plt.plot(x,reg.predict(x), color='blue') 
print(f"Coeff is{reg.coef_} and intercept is {reg.intercept_}")
# the are prefect line and there respective slope is given.
#This slop and intercept is  same as calculated by least sqaure means. (below is the webslite list ,where they calculated
# slop and intercet mathematically using least sqaure means.)
# https://towardsdatascience.com/linear-regression-simplified-ordinary-least-square-vs-gradient-descent-48145de2cf76
#It means/We can say that simple (reg.fit()) model work on simple least sqaure regression to optimize values of 
#intercept and slop. It means reg uses simple  (mean formula) to calculate  m and b.
#++++++++++++
#In above gradient dascent algorithem, as we increase iteration to 10000 , it is apporaching same intercept and slope value.
#So it means that both gradient dascent and least sqaure method  used to calculated best fit line. Answer of both will be same.
#But when multivariate data set comes, then least sqaure method becomes inefficient to calculate. There Gradient dascent 
#work best. In univariate dataset, least sqaure is best.
########+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++##########
# Out:
# Coeff is[[4.7995889]] and intercept is [9.18088386]
