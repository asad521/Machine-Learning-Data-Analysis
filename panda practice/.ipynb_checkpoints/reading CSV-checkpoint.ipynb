# %%
import pandas as pd

# %% [markdown]
# # usecols=[] provide list of columns names or index

# %%
mdf= pd.read_csv("tmdb_5000_movies.csv",usecols=['homepage','revenue']) 
mdf
# Out:
#                                                homepage     revenue
# 0                           http://www.avatarmovie.com/  2787965087
# 1          http://disney.go.com/disneypictures/pirates/   961000000
# 2           http://www.sonypictures.com/movies/spectre/   880674609
# 3                    http://www.thedarkknightrises.com/  1084939099
# 4                  http://movies.disney.com/john-carter   284139100
# ...                                                 ...         ...
# 4798                                                NaN     2040920
# 4799                                                NaN           0
# 4800  http://www.hallmarkchannel.com/signedsealeddel...           0
# 4801                        http://shanghaicalling.com/           0
# 4802                                                NaN           0
#
# [4803 rows x 2 columns]

# %%
mdf= pd.read_csv("tmdb_5000_movies.csv",usecols=[0,2,3,4]) 
mdf
# Out:
#          budget                                           homepage      id  \
# 0     237000000                        http://www.avatarmovie.com/   19995
# 1     300000000       http://disney.go.com/disneypictures/pirates/     285
# 2     245000000        http://www.sonypictures.com/movies/spectre/  206647
# 3     250000000                 http://www.thedarkknightrises.com/   49026
# 4     260000000               http://movies.disney.com/john-carter   49529
# ...         ...                                                ...     ...
# 4798     220000                                                NaN    9367
# 4799       9000                                                NaN   72766
# 4800          0  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801          0                        http://shanghaicalling.com/  126186
# 4802          0                                                NaN   25975
#
#                                                keywords
# ...
