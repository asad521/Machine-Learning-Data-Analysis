# %%
import pandas as pd

# %%
df=pd.read_csv("weatherp.csv")

# %%
df
df.loc[2,['temperature']]=9 
df.loc[3,['temperature']]=9 

df
# Out:
#          date      city  temperature  humidity
# 0  05/01/2017  new york           65        56
# 1  05/02/2017  new york           66        58
# 2  05/03/2017  new york            9        60
# 3  05/01/2017    mumbai            9        80
# 4  05/02/2017    mumbai           78        83
# 5  05/03/2017    mumbai           82        85
# 6  05/01/2017   beijing           80        26
# 7  05/02/2017   beijing           77        30
# 8  05/03/2017   beijing           79        35

# %%
# df1=df.pivot(index="date", columns="city")
# df1
df1=df.pivot(index="date", columns="city", values=["humidity",'temperature']) #only humidity showing

# df.loc[2,['temperature']]=9
df1
# Out:
#            humidity                 temperature
# city        beijing mumbai new york     beijing mumbai new york
# date
# 05/01/2017       26     80       56          80      9       65
# 05/02/2017       30     83       58          77     78       66
# 05/03/2017       35     85       60          79     82        9

# %%
df=pd.read_csv("weatherpp.csv")
df
# Out:
#          date      city  temperature  humidity
# 0  05/01/2017  new york           65        56
# 1  05/01/2017  new york           61        54
# 2  05/02/2017  new york           70        60
# 3  05/02/2017  new york           72        62
# 4  05/01/2017    mumbai           75        80
# 5  05/01/2017    mumbai           78        83
# 6  05/02/2017    mumbai           82        85
# 7  05/02/2017    mumbai           80        26

# %%
df
# Out:
#          date      city  temperature  humidity
# 0  05/01/2017  new york           65        56
# 1  05/01/2017  new york           61        54
# 2  05/02/2017  new york           70        60
# 3  05/02/2017  new york           72        62
# 4  05/01/2017    mumbai           75        80
# 5  05/01/2017    mumbai           78        83
# 6  05/02/2017    mumbai           82        85
# 7  05/02/2017    mumbai           80        26

# %%
df1=df.pivot_table(index="city", columns="date", aggfunc='mean') #it will shows average temperatre based on column and city
df1
# Out:
#            humidity            temperature
# date     05/01/2017 05/02/2017  05/01/2017 05/02/2017
# city
# mumbai         81.5       55.5        76.5       81.0
# new york       55.0       61.0        63.0       71.0

# %%
df1=df.pivot_table(index="city", columns="date", aggfunc=['sum','mean', 'prod']) #it will show sum  temperatre based on column and city
df1
#aggfunc= sum,diff, and many
# Out:
#                 sum                                         mean             \
#            humidity            temperature              humidity
# date     05/01/2017 05/02/2017  05/01/2017 05/02/2017 05/01/2017 05/02/2017
# city
# mumbai          163        111         153        162       81.5       55.5
# new york        110        122         126        142       55.0       61.0
#
#                                       prod
#          temperature              humidity            temperature
# date      05/01/2017 05/02/2017 05/01/2017 05/02/2017  05/01/2017 05/02/2017
# city
# mumbai          76.5       81.0       6640       2210        5850       6560
# new york        63.0       71.0       3024       3720        3965       5040

# %%
df1=df.pivot_table(index="city", columns="date", margins=True, aggfunc='mean') #it will show colum and row wise mean
df1
# Out:
#            humidity                   temperature
# date     05/01/2017 05/02/2017    All  05/01/2017 05/02/2017     All
# city
# mumbai        81.50      55.50  68.50       76.50       81.0  78.750
# new york      55.00      61.00  58.00       63.00       71.0  67.000
# All           68.25      58.25  63.25       69.75       76.0  72.875

# %%
df=pd.read_csv("weatherppp.csv")
df['date']=pd.to_datetime(df['date'])
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
df1=df.pivot_table(index=pd.Grouper(freq="m", key="date"), columns="city") #groupper will group based on date frequency and show average
df1
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %%
df=pd.read_csv("melt.csv")
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df1=pd.melt(df,id_vars=['day'])
df1
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
df1=pd.melt(df,id_vars=['day'], var_name="city", value_name="temperature")
df1
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %%
 df=pd.read_excel("stocks.xlsx", header=[0,1]) #This file has two header/columns/index. Therefore, header list is passed
df
#Inner header is zero , upper is 1
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
a=df.stack() #This command will stack 
# df.index = df.index.droplevel("Facebook")
# Out:
# Index(['Price', 'Price to earnings ratio (P/E)', 'Unnamed: 0_level_0'], dtype='object')

# %%
df.stack(level=0)
# Out:
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
#   Price to earnings ratio (P/E)        NaT     36.78    31.7      30.46
#   Unnamed: 0_level_0            2017-06-07       NaN     NaN        NaN
# 3 Price                                NaT    155.00  1000.0      61.00
#   Price to earnings ratio (P/E)        NaT     36.11    31.2      30.11
#   Unnamed: 0_level_0            2017-06-08       NaN     NaN        NaN
# ...
