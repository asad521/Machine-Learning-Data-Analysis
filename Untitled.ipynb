# %%
import matplotlib.pyplot as plt

# %%
Y=[50,34,53,34,55,77]

# %%
Y
# Out:
# [50, 34, 53, 34, 55, 77]

# %%
Y=[50,34,53,34,55,77]
x=[1,2,3,4,5,6,]
plt.plot(x,Y, color="green", linewidth=3,linestyle='dotted')
plt.ylabel('Temperature')
plt.xlabel('Day')
plt.title('Weather')
plt.plot(x,Y, 'bo--', markersize=10, alpha=0.9)

# %%
x
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
Y
# Out:
# [50, 34, 53, 34, 55, 77]

# %%
plt.plot(x,Y, 'bo--', markersize=10, alpha=0.9)

# %%
 days=[1,2,3,4,5,6,7]

# %%
max_t=[34,38,30,39,31,33,29]

# %%
min_t=[23,24,28,18,23,11,10]

# %%
avg_t=[30,28,22,24,30,16,50]

# %%
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Weather in Pakistan")
plt.plot(days,max_t, label='max')
plt.plot(days,min_t, label='min')
plt.plot(days,avg_t, label= 'ávg')
plt.legend(loc= "best", shadow="true", fontsize="large")
plt.grid()
plt.axes()
# Out:
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':

# %%
import numpy as np

# %%
company=['Abc','Def','Meezan','Hilal']

# %%
revenue=[234,334,66,63]
profit=[121,182,190,101]

# %%
X = np.arange(len(company))
plt.bar(X + 0.00 , revenue, color = 'b', width = 0.25)
plt.bar(X + 0.25, profit, color = 'g', width = 0.25)
plt.xticks(X,company)
plt.xlabel('Company', size=14)
plt.ylabel('Revenue' ,size=14)
plt.title('US Tech Stock', size=15)
# Out:
# Text(0.5, 1.0, 'US Tech Stock')

# %%
blood_sugar=[113,114,155,190,110,159,130,150.117,120,114, 110,200,133,144,122]
blood_sugar2=[113,114,155,190,110,159,130,150.117,120,114, 110,200,133,144,122]
# Out:
#   File "<ipython-input-256-df2cb922ba67>", line 1
#     blood_sugar=[113,114,155,190,110,159,130,150.117,120,114, 110,200,133,144,122
#                                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
expenses=[1000,3242,5004,6000,2000,3434]
cat=['Home rent','Electricity','Education','Transport','Others','Entertainment']
plt.axis('equal')
plt.pie(expenses,labels=cat, radius=1.5, shadow=True,autopct='%1.1f%%',explode=[0,0,0,0.1,0,0], startangle=180)
plt.savefig("pichar.png", bbox_inches='tight', optimize=True)
plt.show()
