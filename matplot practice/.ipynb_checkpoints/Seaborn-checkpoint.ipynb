# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
##Box have satuation and dots have alpha

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x="day", y="total_bill", data=tips, hue='sex')# hue will show in colors.therefore
# only variable with two or only three variation is suitable to be used as hue

# %%
bill=tips['total_bill']
sns.distplot(bill, hist=True,rug=False,kde=True, fit=stats.norm,norm_hist=False)

# %%
sns.boxplot(x=tips['sex'], y=tips['total_bill'], data=tips,hue='day' )# hue will show in colors.therefore
# only variable with two or only three variation is suitable to be used as hue

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
iris= sns.load_dataset("iris")

# %%
sns.boxplot(data=iris, orient="h", palette="autumn")

# %%
sns.boxplot(x=iris["sepal_length"],y=iris["species"] , palette="autumn")
sns.swarmplot(x=iris["sepal_length"],y=iris["species"] , palette="autumn", color=2.5)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(data=tips)#will show the strip plot of coloumn with interger values only

# %%
sns.stripplot(data=iris)

# %%
sns.stripplot(x="total_bill", data=tips)
sns.stripplot(x="sex", y="total_bill", data=tips)#one variable has to numeric'

# %%
sns.stripplot(x="sex", y="total_bill", data=tips, jitter=False,) #straight line output

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=.2,) #disperse output

# %%
sns.stripplot(x="day", y="total_bill", hue="sex",data=tips, jitter=.2,) #disperse output# hue will show in colors.therefore
# only variable with two or only three variation is suitable to be used as hue

# %%
sns.stripplot(x="day", y="total_bill", hue="sex",data=tips,split=True) # Split argument will be split hue variable given x.
# Out:
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\seaborn\categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(x="sex", y="total_bill", hue="day",data=tips,split=True) # Split argument will be split hue variable given x.

# %%
sns.stripplot(x="day", y="total_bill", hue="sex",data=tips,split=True, marker="D", size=10, edgecolor='black',
             alpha=.2)
# marker will change shape of data and size will change marker size
#edge color and alpha will effect the same

# %%
sns.stripplot(x="day", y="total_bill", hue="sex",data=tips,split=True)
sns.boxplot(x="day", y="total_bill", hue="sex",data=tips, color='green', saturation=.1)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Pair plots

x=sns.PairGrid(data=iris) #It is comapring the columns with columns having numerical values
x=x.map(plt.scatter)

# %%
x=sns.PairGrid(data=tips) #It is comapring the columns with columns having numerical values
x=x.map(plt.scatter)

# %%
x=sns.PairGrid(data=iris) #It is comapring the columns with columns having numerical values
x=x.map_diag(plt.hist)# This function will only show diagonal in historgram form

# %%
x=sns.PairGrid(data=iris) #It is comapring the columns with columns having numerical values
x=x.map_diag(plt.hist)# This function will only show diagonal in historgram form
x=x.map_offdiag(plt.scatter)# This is neccessary to show all other graph as well

# %%
x=sns.PairGrid(data=iris, hue="species") #Including the another variable by hue. Will show in color form
x=x.map_diag(plt.hist)# This function will only show diagonal in historgram form
x=x.map_offdiag(plt.scatter)# This is neccessary to show all other graph as well

# %%
x=sns.PairGrid(data=iris, hue="species") #Including the another variable by hue. Will show in color form
x=x.map_diag(plt.hist)# This function will only show diagonal in historgram form
x=x.map_offdiag(plt.scatter)# This is neccessary to show all other graph as well
x=x.add_legend()# To show legend

# %%
x=sns.PairGrid(data=iris, hue="species") #Including the another variable by hue. Will show in color form
x=x.map_diag(plt.hist, histtype='step', linewidth=4)# changing histtype and line width of hist
x=x.map_offdiag(plt.scatter)# This is neccessary to show all other graph as well
x=x.add_legend()# To show legend

# %%
x=sns.PairGrid(data=iris, vars=['sepal_length','petal_length']) # To show relation between specific coloumns
x=x.map(plt.scatter)
x=x.add_legend()
# Out:
# C:\Users\ZEESHAN123\anaconda3\lib\site-packages\seaborn\axisgrid.py:98: UserWarning: The handle <matplotlib.patches.Patch object at 0x0000002805CB01C8> has a label of '_nolegend_' which cannot be automatically added to the legend.
#   figlegend = self.fig.legend(handles, labels, **kwargs)

# %%
x=sns.PairGrid(data=iris, hue='species',vars=['sepal_length','petal_length']) # To show relation between specific coloumns #Adding Hue
x=x.map(plt.scatter)
x=x.add_legend()

# %%
x=sns.PairGrid(data=iris, hue='species',vars=['sepal_length','petal_length']) # To show relation between specific coloumns #Adding Hue
x=x.map_diag(plt.hist)## making diaganle graph as historgraph
x=x.map_offdiag(plt.scatter)##showing other graph as scatter
x=x.add_legend()

# %%
#To interchange x and y , specific which colums you need on x and y by following
x=sns.PairGrid(data=iris, hue='species',x_vars=['petal_length','petal_width'], y_vars=['sepal_length','sepal_width']) 
x=x.map(plt.scatter)##showing other graph as scatter
x=x.add_legend()

# %%
# Can also show x and y axis as per your need
x=sns.PairGrid(data=iris, hue='species',x_vars=['petal_length'], y_vars=['sepal_length','sepal_width']) 
x=x.map(plt.scatter)##showing other graph as scatter
x=x.add_legend()

# %%
# To show different types of plat accors diagnal use 
x=sns.PairGrid(data=iris, hue='species') 
x=x.map_diag(plt.hist)##specificy diagonal graph type
x=x.map_upper(sns.kdeplot)###specificy upper diagonal graph type
x=x.map_lower(plt.scatter)###specificy lower diagonal graph type
x=x.add_legend()

# %%
# Here we will change marker style for hue .
x=sns.PairGrid(data=iris, hue='species', hue_kws={'marker':['D','s','+']}) #Since we have 3 hue variable. We will pass dic with list
x=x.map(plt.scatter, s=30)
x=x.add_legend()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(tips['total_bill'])

# %%
sns.violinplot(x=tips['total_bill'], y= tips['sex']) #one must be numerical and other should be categorical for better visual

# %%
 sns.violinplot(x='day', y= 'total_bill', hue='sex', data=tips) #adding hue

# %%
 sns.violinplot(x='day', y= 'total_bill', hue='sex', data=tips, split=True) #Splitted the graph by  hue into two violin

# %%
 sns.violinplot(x='day', y= 'total_bill', hue='sex', data=tips, split=True, inner='quartile') #Inner quartile is showing horizentally

# %%
 sns.violinplot(x='day', y= 'total_bill', hue='sex' , data=tips, inner='quartile', scale='count') #Violin shape is adjusted by count

# %%
flights=sns.load_dataset("flights")

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
flights=flights.pivot('month','year','passengers')
flights
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(flights) # heat map showing frequency of passenger based on ordered months and year

# %%
sns.clustermap(flights)# Cluster map showing similar/cluster of passenger based on both year and month

# %%
sns.clustermap(flights, col_cluster=False)# Shoing only similar/cluster of passenger based on rows only. 
#rows are month based on pivot table
#there rows/month are unordered

# %%
sns.clustermap(flights, row_cluster=False)# Shoing only similar/cluster of passenger based on col only.

# %%
sns.clustermap(flights, row_cluster=False, cmap="coolwarm", linewidth=1)
#chaining line width and color

# %%
sns.clustermap(flights, row_cluster=False, cmap="coolwarm", linewidth=1, figsize=(8,8))
#chaingn size

# %%
sns.clustermap(flights, cmap="coolwarm", linewidth=1, figsize=(8,8), standard_scale=0)
#standardzing data accross  row 0 row and 1 columns

# %%
sns.clustermap(flights, cmap="coolwarm", linewidth=1, z_score=0)
#standardzing data accross  row #0 row and 1 colomuns
